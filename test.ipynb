# %%
HEART_PREDICTOR_MODEL_CODE = {
    'LogisticRegression':1,
    'KNeighborsClassifier':2,
    'DecisionTreeClassifier':3,
    'SVC':4
}

# %%
codes = {value: key for key, value in HEART_PREDICTOR_MODEL_CODE.items()}

# %%
codes.get(2)
# Out:
# 'KNeighborsClassifier'

# %%
HEART_PREDICTOR_MODEL_CODE.values()
# Out:
# dict_values([1, 2, 3, 4])
